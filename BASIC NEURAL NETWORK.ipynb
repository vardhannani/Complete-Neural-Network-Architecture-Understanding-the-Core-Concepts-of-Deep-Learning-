# %%
# Import necessary libraries
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
import numpy as np

# Load the Iris dataset
iris = load_iris()
X = iris.data  # Features
y = iris.target  # Target labels

# %%
# Load the Iris dataset
iris = load_iris()
X = iris.data  # Features
y = iris.target  # Target labels

# %%
# Preprocess the data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# Encode the labels into one-hot vectors
encoder = LabelEncoder()
y_encoded = encoder.fit_transform(y)
y_one_hot = tf.keras.utils.to_categorical(y_encoded, num_classes=3)

# %%
# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_one_hot, test_size=0.2, random_state=42)

# %%
# Build the neural network model
model = Sequential()

# %%
# Add input layer (4 features) and first hidden layer with 64 neurons and ReLU activation
model.add(Dense(64, input_dim=4, activation='relu'))

# Add another hidden layer with 32 neurons
model.add(Dense(32, activation='relu'))

# Add output layer (3 classes for Iris dataset)
model.add(Dense(3, activation='softmax'))

# Compile the model with categorical cross-entropy loss and Adam optimizer
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# Train the model
history = model.fit(X_train, y_train, epochs=100, batch_size=10, validation_split=0.2)
# Out:
# Epoch 1/100
# 10/10 [==============================] - 1s 21ms/step - loss: 0.9816 - accuracy: 0.6250 - val_loss: 0.9788 - val_accuracy: 0.4583
# Epoch 2/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.8005 - accuracy: 0.7188 - val_loss: 0.8583 - val_accuracy: 0.5833
# Epoch 3/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6777 - accuracy: 0.7917 - val_loss: 0.7600 - val_accuracy: 0.7917
# Epoch 4/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5881 - accuracy: 0.8021 - val_loss: 0.6730 - val_accuracy: 0.8333
# Epoch 5/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5159 - accuracy: 0.8229 - val_loss: 0.6013 - val_accuracy: 0.8333
# Epoch 6/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4573 - accuracy: 0.8021 - val_loss: 0.5337 - val_accuracy: 0.8333
# Epoch 7/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4125 - accuracy: 0.8125 - val_loss: 0.4828 - val_accuracy: 0.8750
# Epoch 8/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3778 - accuracy: 0.8229 - val_loss: 0.4499 - val_accuracy: 0.8750
# Epoch 9/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3539 - accuracy: 0.8229 - val_loss: 0.4277 - val_accuracy: 0.8750
# Epoch 10/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3341 - accuracy: 0.8229 - val_loss: 0.4068 - val_accuracy: 0.8750
# Epoch 11/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3146 - accuracy: 0.8229 - val_loss: 0.4017 - val_accuracy: 0.8750
# Epoch 12/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3009 - accuracy: 0.8229 - val_loss: 0.3969 - val_accuracy: 0.8750
# Epoch 13/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2839 - accuracy: 0.8438 - val_loss: 0.3798 - val_accuracy: 0.9167
# Epoch 14/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2681 - accuracy: 0.8438 - val_loss: 0.3723 - val_accuracy: 0.9167
# Epoch 15/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2528 - accuracy: 0.8854 - val_loss: 0.3572 - val_accuracy: 0.9167
# Epoch 16/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2374 - accuracy: 0.9062 - val_loss: 0.3483 - val_accuracy: 0.9167
# Epoch 17/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2272 - accuracy: 0.8854 - val_loss: 0.3276 - val_accuracy: 0.9167
# Epoch 18/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2098 - accuracy: 0.9271 - val_loss: 0.3299 - val_accuracy: 0.9583
# Epoch 19/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1975 - accuracy: 0.9271 - val_loss: 0.3300 - val_accuracy: 0.9583
# Epoch 20/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1849 - accuracy: 0.9375 - val_loss: 0.3095 - val_accuracy: 0.9583
# Epoch 21/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1724 - accuracy: 0.9375 - val_loss: 0.2903 - val_accuracy: 0.9583
# Epoch 22/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1611 - accuracy: 0.9479 - val_loss: 0.2868 - val_accuracy: 0.9583
# Epoch 23/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1509 - accuracy: 0.9479 - val_loss: 0.2898 - val_accuracy: 0.9583
# Epoch 24/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1406 - accuracy: 0.9479 - val_loss: 0.2605 - val_accuracy: 0.9583
# Epoch 25/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1369 - accuracy: 0.9375 - val_loss: 0.2731 - val_accuracy: 0.9167
# Epoch 26/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1248 - accuracy: 0.9479 - val_loss: 0.2437 - val_accuracy: 0.9583
# Epoch 27/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1224 - accuracy: 0.9479 - val_loss: 0.2529 - val_accuracy: 0.9583
# Epoch 28/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1182 - accuracy: 0.9583 - val_loss: 0.2356 - val_accuracy: 0.9583
# Epoch 29/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1144 - accuracy: 0.9479 - val_loss: 0.2705 - val_accuracy: 0.9167
# Epoch 30/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1041 - accuracy: 0.9583 - val_loss: 0.2422 - val_accuracy: 0.9583
# Epoch 31/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1018 - accuracy: 0.9688 - val_loss: 0.2392 - val_accuracy: 0.9583
# Epoch 32/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0991 - accuracy: 0.9583 - val_loss: 0.2656 - val_accuracy: 0.9167
# Epoch 33/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0983 - accuracy: 0.9583 - val_loss: 0.2412 - val_accuracy: 0.9167
# Epoch 34/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0966 - accuracy: 0.9479 - val_loss: 0.2689 - val_accuracy: 0.9167
# Epoch 35/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0906 - accuracy: 0.9583 - val_loss: 0.2371 - val_accuracy: 0.9583
# Epoch 36/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0869 - accuracy: 0.9583 - val_loss: 0.2418 - val_accuracy: 0.9167
# Epoch 37/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0828 - accuracy: 0.9583 - val_loss: 0.2585 - val_accuracy: 0.9167
# Epoch 38/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0825 - accuracy: 0.9688 - val_loss: 0.2683 - val_accuracy: 0.9167
# Epoch 39/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0808 - accuracy: 0.9792 - val_loss: 0.2525 - val_accuracy: 0.9167
# Epoch 40/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0817 - accuracy: 0.9583 - val_loss: 0.2386 - val_accuracy: 0.9167
# Epoch 41/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0763 - accuracy: 0.9688 - val_loss: 0.2627 - val_accuracy: 0.9167
# Epoch 42/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0789 - accuracy: 0.9792 - val_loss: 0.2842 - val_accuracy: 0.9167
# Epoch 43/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0789 - accuracy: 0.9688 - val_loss: 0.2257 - val_accuracy: 0.9583
# Epoch 44/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0791 - accuracy: 0.9583 - val_loss: 0.2768 - val_accuracy: 0.9167
# Epoch 45/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0726 - accuracy: 0.9792 - val_loss: 0.2624 - val_accuracy: 0.9167
# Epoch 46/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0711 - accuracy: 0.9792 - val_loss: 0.2569 - val_accuracy: 0.9167
# Epoch 47/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0708 - accuracy: 0.9688 - val_loss: 0.2320 - val_accuracy: 0.9167
# Epoch 48/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0695 - accuracy: 0.9583 - val_loss: 0.2529 - val_accuracy: 0.9167
# Epoch 49/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0713 - accuracy: 0.9792 - val_loss: 0.2924 - val_accuracy: 0.9167
# Epoch 50/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0673 - accuracy: 0.9792 - val_loss: 0.2554 - val_accuracy: 0.9167
# Epoch 51/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0666 - accuracy: 0.9583 - val_loss: 0.2543 - val_accuracy: 0.9167
# Epoch 52/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0665 - accuracy: 0.9688 - val_loss: 0.2705 - val_accuracy: 0.9167
# Epoch 53/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0650 - accuracy: 0.9792 - val_loss: 0.2797 - val_accuracy: 0.9167
# Epoch 54/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0682 - accuracy: 0.9688 - val_loss: 0.2485 - val_accuracy: 0.9167
# Epoch 55/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0626 - accuracy: 0.9688 - val_loss: 0.2752 - val_accuracy: 0.9167
# Epoch 56/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0665 - accuracy: 0.9688 - val_loss: 0.3225 - val_accuracy: 0.9167
# Epoch 57/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0632 - accuracy: 0.9792 - val_loss: 0.2570 - val_accuracy: 0.9167
# Epoch 58/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0616 - accuracy: 0.9792 - val_loss: 0.2736 - val_accuracy: 0.9167
# Epoch 59/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0621 - accuracy: 0.9792 - val_loss: 0.2772 - val_accuracy: 0.9167
# Epoch 60/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0613 - accuracy: 0.9792 - val_loss: 0.2742 - val_accuracy: 0.9167
# Epoch 61/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0614 - accuracy: 0.9792 - val_loss: 0.2931 - val_accuracy: 0.9167
# Epoch 62/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0592 - accuracy: 0.9792 - val_loss: 0.2793 - val_accuracy: 0.9167
# Epoch 63/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0605 - accuracy: 0.9792 - val_loss: 0.2744 - val_accuracy: 0.9167
# Epoch 64/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0588 - accuracy: 0.9792 - val_loss: 0.2844 - val_accuracy: 0.9167
# Epoch 65/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0580 - accuracy: 0.9792 - val_loss: 0.2837 - val_accuracy: 0.9167
# Epoch 66/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0574 - accuracy: 0.9792 - val_loss: 0.2823 - val_accuracy: 0.9167
# Epoch 67/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0592 - accuracy: 0.9688 - val_loss: 0.2626 - val_accuracy: 0.9167
# Epoch 68/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0571 - accuracy: 0.9792 - val_loss: 0.3046 - val_accuracy: 0.9167
# Epoch 69/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0594 - accuracy: 0.9792 - val_loss: 0.3168 - val_accuracy: 0.9167
# Epoch 70/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0634 - accuracy: 0.9688 - val_loss: 0.2629 - val_accuracy: 0.9583
# Epoch 71/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0591 - accuracy: 0.9792 - val_loss: 0.3189 - val_accuracy: 0.9167
# Epoch 72/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0554 - accuracy: 0.9792 - val_loss: 0.3034 - val_accuracy: 0.9167
# Epoch 73/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0591 - accuracy: 0.9688 - val_loss: 0.2730 - val_accuracy: 0.9167
# Epoch 74/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0544 - accuracy: 0.9792 - val_loss: 0.2901 - val_accuracy: 0.9167
# Epoch 75/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0547 - accuracy: 0.9792 - val_loss: 0.3351 - val_accuracy: 0.9167
# Epoch 76/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0535 - accuracy: 0.9792 - val_loss: 0.3031 - val_accuracy: 0.9167
# Epoch 77/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0578 - accuracy: 0.9688 - val_loss: 0.2732 - val_accuracy: 0.9167
# Epoch 78/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0521 - accuracy: 0.9792 - val_loss: 0.3036 - val_accuracy: 0.9167
# Epoch 79/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0515 - accuracy: 0.9792 - val_loss: 0.3214 - val_accuracy: 0.9167
# Epoch 80/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0547 - accuracy: 0.9792 - val_loss: 0.3405 - val_accuracy: 0.9167
# Epoch 81/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0499 - accuracy: 0.9792 - val_loss: 0.3081 - val_accuracy: 0.9167
# Epoch 82/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0521 - accuracy: 0.9896 - val_loss: 0.2756 - val_accuracy: 0.9167
# Epoch 83/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0517 - accuracy: 0.9792 - val_loss: 0.2992 - val_accuracy: 0.9167
# Epoch 84/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0528 - accuracy: 0.9792 - val_loss: 0.3009 - val_accuracy: 0.9167
# Epoch 85/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0500 - accuracy: 0.9792 - val_loss: 0.3389 - val_accuracy: 0.9167
# Epoch 86/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0508 - accuracy: 0.9792 - val_loss: 0.3266 - val_accuracy: 0.9167
# Epoch 87/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0497 - accuracy: 0.9792 - val_loss: 0.3226 - val_accuracy: 0.9167
# Epoch 88/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0484 - accuracy: 0.9792 - val_loss: 0.3298 - val_accuracy: 0.9167
# Epoch 89/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0494 - accuracy: 0.9792 - val_loss: 0.3423 - val_accuracy: 0.9167
# Epoch 90/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0489 - accuracy: 0.9792 - val_loss: 0.3290 - val_accuracy: 0.9167
# Epoch 91/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0478 - accuracy: 0.9792 - val_loss: 0.3268 - val_accuracy: 0.9167
# Epoch 92/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0479 - accuracy: 0.9792 - val_loss: 0.3322 - val_accuracy: 0.9167
# Epoch 93/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0479 - accuracy: 0.9792 - val_loss: 0.3319 - val_accuracy: 0.9167
# Epoch 94/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0471 - accuracy: 0.9792 - val_loss: 0.3327 - val_accuracy: 0.9167
# Epoch 95/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0465 - accuracy: 0.9792 - val_loss: 0.3351 - val_accuracy: 0.9167
# Epoch 96/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0467 - accuracy: 0.9792 - val_loss: 0.3345 - val_accuracy: 0.9167
# Epoch 97/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0487 - accuracy: 0.9792 - val_loss: 0.3493 - val_accuracy: 0.9167
# Epoch 98/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0473 - accuracy: 0.9792 - val_loss: 0.3137 - val_accuracy: 0.9167
# Epoch 99/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0460 - accuracy: 0.9792 - val_loss: 0.3359 - val_accuracy: 0.9167
# Epoch 100/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0495 - accuracy: 0.9792 - val_loss: 0.3673 - val_accuracy: 0.9167

# %%
# Evaluate the model on the test data
loss, accuracy = model.evaluate(X_test, y_test)
print(f'Test Loss: {loss}')
print(f'Test Accuracy: {accuracy}')
# Out:
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0156 - accuracy: 1.0000
# Test Loss: 0.015573902986943722
# Test Accuracy: 1.0

# %%
# Predict using the trained model
predictions = model.predict(X_test)

# %%
# Convert predictions from one-hot to class labels
predicted_classes = np.argmax(predictions, axis=1)
true_classes = np.argmax(y_test, axis=1)

print(f'Predicted classes: {predicted_classes[:5]}')
print(f'True classes: {true_classes[:5]}')
# Out:
# Predicted classes: [1 0 2 1 1]
# True classes: [1 0 2 1 1]
